# %%
import pandas

# %%
df = pandas.DataFrame([[3,4,5,6],[7,8,9,0]])

# %%
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>4</td>
#       <td>5</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>7</td>
#       <td>8</td>
#       <td>9</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Address</th>
#       <th>City</th>
#       <th>State</th>
#       <th>Country</th>
#       <th>Name</th>
#       <th>Employees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>3666 21st St</td>
#       <td>San Francisco</td>
#       <td>CA 94114</td>
#       <td>USA</td>
#       <td>Madeira</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>735 Dolores St</td>
#       <td>San Francisco</td>
#       <td>CA 94119</td>
#       <td>USA</td>
#       <td>Bready Shop</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>332 Hill St</td>
#       <td>San Francisco</td>
#       <td>California 94114</td>
#       <td>USA</td>
#       <td>Super River</td>
#       <td>25</td>
#     </tr>
#     <tr>
# ...

# %%
from geopy.geocoders import Nominatim
n = Nominatim()
co = n.geocode("94 Niagara ave, San Francisco, CA 94112")
print(co)
# Out:
# 94, Niagara Avenue, Crocker-Amazon, SF, California, 94112, United States of America

# %%
df["passadr"]=df["Address"] + ", " + df["City"]+ ", "+ df["State"]

# %%
df["Coordinates"]=df["passadr"].apply(n.geocode)

# %%
df["Latitude"]= df["Coordinates"].apply(lambda x : x.longitude if x != None else None )

# %%
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ID</th>
#       <th>Address</th>
#       <th>City</th>
#       <th>State</th>
#       <th>Country</th>
#       <th>Name</th>
#       <th>Employees</th>
#       <th>passadr</th>
#       <th>Coordinates</th>
#       <th>Latitude</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>3666 21st St</td>
#       <td>San Francisco</td>
#       <td>CA 94114</td>
#       <td>USA</td>
#       <td>Madeira</td>
#       <td>8</td>
#       <td>3666 21st St, San Francisco, CA 94114</td>
#       <td>(3666, 21st Street, Noe Valley, SF, California...</td>
#       <td>-122.429343</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>735 Dolores St</td>
#       <td>San Francisco</td>
#       <td>CA 94119</td>
#       <td>USA</td>
#       <td>Bready Shop</td>
#       <td>15</td>
# ...

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-72fbbcfe2587> in <module>()
# ----> 1 import cv2
#
# C:\Users\Vasyl\Anaconda3\lib\site-packages\cv2\__init__.py in <module>()
#       5 os.environ["PATH"] += os.pathsep + os.path.dirname(os.path.realpath(__file__))
#       6
# ----> 7 from . import cv2
#       8 sys.modules['cv2'] = cv2
#
# ImportError: DLL load failed: %1 is not a valid Win32 application.

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-72fbbcfe2587> in <module>()
# ----> 1 import cv2
#
# C:\Users\Vasyl\Anaconda3\lib\site-packages\cv2\__init__.py in <module>()
#       5 os.environ["PATH"] += os.pathsep + os.path.dirname(os.path.realpath(__file__))
#       6
# ----> 7 from . import cv2
#       8 sys.modules['cv2'] = cv2
#
# ImportError: DLL load failed: %1 is not a valid Win32 application.
